# %% [markdown]
# Here is first step to convert review file to csv

# %%
import csv
import re
import requests

# Specify the input and output file paths
input_url = 'https://github.com/Vovanch0/sentiment-analysis-isy503/raw/main/data/dvd_positive.review'
output_file = 'dvd_positive.csv'

# Download the content of the .review file from the URL
response = requests.get(input_url)
data = response.text


# Split the data into individual reviews
reviews = re.findall(r'<review>(.*?)</review>', data, re.DOTALL)

# Prepare the CSV file headers
headers = [
    'unique_id', 'asin', 'product_name', 'product_type', 'helpful',
    'rating', 'title', 'date', 'reviewer', 'reviewer_location', 'review_text'
]


# Open a CSV file for writing
with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=headers)
    writer.writeheader()

    # Iterate through each review and extract the fields
    for review in reviews:
        review_dict = {}
        for header in headers:
            pattern = f'<{header}>(.*?)</{header}>'
            match = re.search(pattern, review, re.DOTALL)
            review_dict[header] = match.group(1).strip() if match else ''

        # Write the row to the CSV
        writer.writerow(review_dict)

print(f"CSV file '{output_file}' created successfully.")
# Out:
# CSV file 'dvdpos.csv' created successfully.

# %% [markdown]
# Local save from virtual Google colab fs

# %%
from google.colab import files
files.download('dvd_positive.csv')

# %% [markdown]
# Merge all csv file to one csv

# %%
import os
import pandas as pd

def merge_csv_files(folder_path, output_file):
    # List to hold all the dataframes
    all_dataframes = []

    # Iterate over all files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".csv"):
            csv_file = os.path.join(folder_path, filename)
            # Read the CSV file into a DataFrame
            df = pd.read_csv(csv_file)
            all_dataframes.append(df)

    # Concatenate all DataFrames
    merged_df = pd.concat(all_dataframes, ignore_index=True)

    # Write the merged DataFrame to a new CSV file
    merged_df.to_csv(output_file, index=False)

folder_path = "C:/503/final"  # Replace with your folder path
output_file = "C:/503/final/merged_output.csv"    # Name of the output file

merge_csv_files(folder_path, output_file)

# %% [markdown]
# After that, I have uploaded this file to github.
#
# Link
# https://github.com/Vovanch0/sentiment-analysis-isy503/raw/main/data/merged_output.csv

# %%
import pandas as pd
data = pd.read_csv('https://github.com/Vovanch0/sentiment-analysis-isy503/raw/main/data/merged_output.csv',
                   sep=',', encoding='utf8')

print('Number of reviews', str(len(data)))
# Out:
# Number of reviews 8000

# %%
data.head(15)
# Out:
#                                             unique_id        asin  \
# 0     0312355645:horrible_book,_horrible.:mark_gospri  0312355645
# 1   1559278676:shallow_self-indulgence:joseph_s._p...  1559278676
# 2     1559278676:horrible_book,_horrible.:mark_gospri  1559278676
# 3           0425193373:disappointment:reader_"reader"  0425193373
# 4             0142004030:a_disappointing_mess:a._ross  0142004030
# 5   0895261537:save_your_money,_there_are_better_b...  0895261537
# 6   0140444394:thank_you,_but_no,_thanks:michael_s...  0140444394
# 7    0380725835:unendurable_:w._d._amato_"drumturtle"  0380725835
# 8                1423306384:the_hard_way:h._d._zabitz  1423306384
# 9   0060764686:some_good_info_among_the_political_...  0060764686
# 10  0805076158:interesting_reading,_but_take_it_wi...  0805076158
# 11       0842329277:the_half-way_mark:dr._m._a._ramos  0842329277
# 12  0679750541:a_book_intended_to_deflect_attentio...  0679750541
# 13  1585424226:is_this_book_made_of_100%_american_...  1585424226
# 14       0876859260:bukowski's_worst_book:bog_trotter  0876859260
#
#                                          product_name product_type   helpful  \
# 0   Running with Scissors: A Memoir: Books: August...        books    4 of 9
# 1   Running with Scissors: A Memoir: Books: August...        books    1 of 6
# 2   Running with Scissors: A Memoir: Books: August...        books    4 of 9
# 3   Fierce Conversations: Achieving Sucess at Work...        books  10 of 13
# 4   Lost in a Good Book (Thursday Next Novels): Bo...        books    6 of 7
# 5   What's So Great About America: Books: Dinesh D...        books   9 of 41
# 6   A Discourse on Inequality (Penguin Classics): ...        books   7 of 33
# 7   Endangered Species (Anna Pigeon Mysteries (Pap...        books    2 of 7
# 8   Hard Way, The (Jack Reacher): Books: Lee Child...        books    0 of 4
# 9   Understanding Iraq: The Whole Sweep of Iraqi H...        books    3 of 7
# 10  Chinese Lessons: Five Classmates and the Story...        books    0 of 1
# 11  Assassins: Assignment: Jerusalem, Target: Anti...        books    9 of 9
# 12     Culture and Imperialism: Books: Edward W. Said        books  19 of 71
# 13  The United States of Wal-Mart: Books: John Dicker        books   5 of 38
# 14                      Pulp: Books: Charles Bukowski        books    2 of 6
#
#     rating                                              title  \
# 0      1.0                           Horrible book, horrible.
# 1      1.0                            shallow self-indulgence
# 2      1.0                           Horrible book, horrible.
# 3      1.0                                     Disappointment
# 4      2.0                               A Disappointing Mess
# 5      2.0  Save your money, there are better books out there
# 6      1.0                          Thank you, but no, thanks
# 7      1.0                                        Unendurable
# 8      1.0                                       The Hard Way
# 9      2.0      Some good info among the political commercial
# 10     2.0  Interesting reading, but take it with a grain ...
# 11     2.0                                  The Half-way mark
# 12     1.0  A book intended to deflect attention from Arab...
# 13     1.0  Is This BOOK Made Of 100% American Products? N...
# 14     1.0                              Bukowski's worst book
#
#                   date                         reviewer  \
# 0    November 14, 2006                      Mark Gospri
# 1    November 15, 2006  Joseph S. Perrott "avid reader"
# 2    November 14, 2006                      Mark Gospri
# 3       March 13, 2006                  Reader "Reader"
# 4         May 17, 2006                          A. Ross
# 5      August 18, 2005                      CaliChrissy
# 6        June 13, 2001                  Michael Sympson
# 7       March 15, 2005         W. D. Amato "Drumturtle"
# 8     November 9, 2006                     H. D. Zabitz
# 9         July 4, 2006             Neil Bacon "Patriot"
# 10   November 17, 2006                     Tennyson Lee
# 11  September 27, 2005                  Dr. M. A. Ramos
# 12         May 1, 2005                     Adel Makhoul
# 13   December 14, 2005                  Edmond Gauthier
# 14     August 11, 2004                      Bog Trotter
#
#                   reviewer_location  \
# 0                               NaN
# 1   philadelphia, pa. United States
# 2                               NaN
# 3                               NaN
# 4                    Washington, DC
# 5                    Santa Cruz, CA
# 6                         Singapore
# 7                             Japan
# 8                     Bethlehem, PA
# 9              Williamsburg, VA USA
# 10                      Rocklin, CA
# 11                Melbourne, FL USA
# 12                   Beirut Lebanon
# 13                              USA
# 14                  Madison, WI USA
#
#                                           review_text
# 0   THis book was horrible.  If it was possible to...
# 1   I like to use the Amazon reviews when purchasi...
# 2   THis book was horrible.  If it was possible to...
# 3   I'm not sure who's writing these reviews, but ...
# 4   I picked up the first book in this series (The...
# 5   Not only do I disagree with his opinions, but ...
# 6   &quot;I have received your new book against th...
# 7   This book was on somebody's Amazon.com LISTMAN...
# 8   I am not sure whatever possessed me to buy thi...
# 9   When Professor Polk describes the sweep of his...
# 10  This is a story of the lives of 5 people who a...
# 11  This is the sixth book in the Left Behind seri...
# 12  This book is essentially about how culture is ...
# 13  Oh, yes - this is a very fine book... for me t...
# 14  Hands down this is Bukowski's single worst boo...

# %% [markdown]
# Let's see unique values in the 'rating'

# %%
data['rating'].unique()
# Out:
# array([1., 2., 5., 4.])

# %% [markdown]
# Clean data | Speller

# %%
# !pip install autocorrect
from autocorrect import Speller

# Set language to Eng
spell = Speller(lang='en')

# Define autocorrect function
def autocorrect(text):
    return spell(text)

# Apply autocorrect
data['review_text_correct'] = data['review_text'].apply(autocorrect)

# Save the cleaned data to a CSV file
output_file = 'cleaned_reviews.csv'
data.to_csv(output_file, index=False, encoding='utf-8')

print(f"Cleaned data saved to '{output_file}'")
# Out:
# Requirement already satisfied: autocorrect in /usr/local/lib/python3.10/dist-packages (2.6.1)
# Cleaned data saved to 'cleaned_reviews.csv'

# %%
from google.colab import files
files.download(output_file)

# %%
pd.options.display.max_colwidth = 250

data.loc[9, ['review_text', 'review_text_correct']]
# Out:
# review_text            When Professor Polk describes the sweep of history in Iraq, he is at his best, but the book often descends into a political diatribe that is neither appropriate nor grounded in the facts.  Much of the political ranting is supposition, marring wha...
# review_text_correct    When Professor Poll describes the sweep of history in Iraq, he is at his best, but the book often descends into a political diatribe that is neither appropriate nor grounded in the facts.  Much of the political ranting is opposition, warring what...
# Name: 9, dtype: object
